# %% [markdown]
# *Asignacion de estudiantes en base a la malla curricular*

# %%
import pandas as pd
import random
import os
import datetime
import platform

def log_event(message):
    print(message)

# Encabezado del log con información del sistema y usuario
system_info = platform.uname()
print(f"Sistema: {system_info.system}")
print(f"Nodo: {system_info.node}")
print(f"Release: {system_info.release}")
print(f"Versión: {system_info.version}")
print(f"Máquina: {system_info.machine}")
print(f"Procesador: {system_info.processor}")
print(f"_____________________________________________________________________________________")

# Función para leer nombres y apellidos de los archivos proporcionados
def read_names(file):
    try:
        return pd.read_csv(file, header=None, skiprows=1, encoding='utf-8').squeeze().tolist()
    except Exception as e:
        log_event(f"Error leyendo el archivo {file}: {e}")
        return []

# Generación de datos únicos para los estudiantes
def generate_students(num_students, first_names, last_names):
    students = []
    unique_names = set()
    while len(students) < num_students:
        full_name = f"{random.choice(first_names)} {random.choice(last_names)}"
        if full_name not in unique_names:
            unique_names.add(full_name)
            students.append({'Nombre Completo': full_name})
    return students

# Distribución de estudiantes entre los semestres
def distribute_students(students):
    distribution = [0.14, 0.13, 0.12, 0.11, 0.10, 0.10, 0.09, 0.08, 0.07, 0.06]
    if sum(distribution) != 1.0:
        raise ValueError("La suma de las proporciones de distribución no es igual a 1")
    semester_counts = [int(len(students) * p) for p in distribution]
    semesters = []
    for i, count in enumerate(semester_counts):
        semesters.extend([i + 1] * count)
    random.shuffle(semesters)
    for student, semester in zip(students, semesters):
        student['Semestre'] = semester
    return students

# Función para obtener las iniciales del curso
def obtener_iniciales(nombre):
    palabras_comunes = {"DE", "LA", "DEL", "Y", "EL", "LOS", "LAS"}
    palabras = nombre.split()
    iniciales = [palabra[:3] for palabra in palabras if palabra.upper() not in palabras_comunes]
    return "".join(iniciales).upper()[:3]

# Función para calcular HTD y HTI basadas en los créditos
def calcular_horas(creditos):
    if creditos == 4:
        return 96, 120
    if creditos == 3:
        return 64, 80
    if creditos == 2:
        return 32, 64
    if creditos == 1:
        return 16, 32
    return 0, 0

# Generar el código único para cada materia
def generar_codigo(nombre, nivel, creditos, consecutivo):
    iniciales = obtener_iniciales(nombre)
    return f"{iniciales}{nivel}{creditos}{consecutivo}"

# Crear archivos de cursos
def create_course_files(students, courses, folder_path):
    start_time = datetime.datetime.now()
    log_event("Inicio de la creación de archivos de cursos")

    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
    grouped = {course: [] for course in courses}

    for student in students:
        for course, info in courses.items():
            if student['Semestre'] in info['Semestres']:
                grouped[course].append(student)

    for course, data in grouped.items():
        course_path = os.path.join(folder_path, f"Semestre {courses[course]['Semestres'][0]}", course)
        if not os.path.exists(course_path):
            os.makedirs(course_path)
        num_groups = len(data) // courses[course]['Cupo'] + (1 if len(data) % courses[course]['Cupo'] else 0)
        tca = num_groups  # Total de cursos asignados
        nte = len(data)  # Número total de estudiantes en la asignatura
        fecha_creacion = datetime.datetime.now().strftime('%Y/%m/%d')  # Fecha de creación
        for i in range(num_groups):
            group_data = data[i * courses[course]['Cupo']:(i + 1) * courses[course]['Cupo']]
            if group_data:

                for student in group_data:
                    student['HTD'] = courses[course]['HTD']
                    student['HTI'] = courses[course]['HTI']
                df = pd.DataFrame(group_data)[['Nombre Completo', 'Semestre', 'HTD', 'HTI']]
                df['NTE'] = nte
                df['CC'] = i + 1
                df['TCA'] = tca
                df['FC'] = fecha_creacion

                code = course
                course_name = courses[course]['Nombre'].replace(" ", "").capitalize()
                student_count = len(group_data)
                group_code = i + 1
                filename = f"{code}-{course_name}-{student_count}-{group_code}"
                filepath_csv = os.path.join(course_path, f"{filename}.csv")
                filepath_excel = os.path.join(course_path, f"{filename}.xlsx")

                # Crear archivo CSV
                csv_start_time = datetime.datetime.now()
                df.to_csv(filepath_csv, index=False, encoding='utf-8-sig')
                csv_end_time = datetime.datetime.now()
                csv_time_taken = csv_end_time - csv_start_time
                log_event(f'Creado archivo CSV: {filepath_csv}. Tiempo: {csv_time_taken}')

                # Crear archivo Excel
                excel_start_time = datetime.datetime.now()
                df.to_excel(filepath_excel, index=False)
                excel_end_time = datetime.datetime.now()
                excel_time_taken = excel_end_time - excel_start_time
                log_event(f'Creado archivo Excel: {filepath_excel}. Tiempo: {excel_time_taken}')

    end_time = datetime.datetime.now()
    total_time_taken = end_time - start_time
    log_event(f"Fin de la creación de archivos de cursos. Tiempo total: {total_time_taken}")

# Lista de materias con información
materias = [
    {"nivel": 1, "nombre": "INGLÉS I", "creditos": 1},
    {"nivel": 1, "nombre": "INTRODUCCIÓN A LA INGENIERÍA INDUSTRIAL", "creditos": 1},
    {"nivel": 1, "nombre": "ÁLGEBRA Y TRIGONOMETRÍA", "creditos": 3},
    {"nivel": 1, "nombre": "GEOMETRÍA VECTORIAL Y ANALÍTICA", "creditos": 3},
    {"nivel": 1, "nombre": "CÁLCULO DIFERENCIAL", "creditos": 3},
    {"nivel": 1, "nombre": "LECTOESCRITURA", "creditos": 3},
    {"nivel": 1, "nombre": "VIVAMOS LA UNIVERSIDAD", "creditos": 1},
    {"nivel": 2, "nombre": "INGLÉS II", "creditos": 1},
    {"nivel": 2, "nombre": "GESTIÓN DE LAS ORGANIZACIONES", "creditos": 3},
    {"nivel": 2, "nombre": "HABILIDADES GERENCIALES", "creditos": 3},
    {"nivel": 2, "nombre": "ÁLGEBRA LINEAL", "creditos": 3},
    {"nivel": 2, "nombre": "CÁLCULO INTEGRAL", "creditos": 3},
    {"nivel": 2, "nombre": "DESCUBRIENDO LA FÍSICA", "creditos": 3},
    {"nivel": 3, "nombre": "INGLÉS III", "creditos": 1},
    {"nivel": 3, "nombre": "GESTIÓN CONTABLE", "creditos": 3},
    {"nivel": 3, "nombre": "TEORÍA GENERAL DE SISTEMAS", "creditos": 3},
    {"nivel": 3, "nombre": "PROBABILIDAD E INFERENCIA ESTADÍSTICA", "creditos": 3},
    {"nivel": 3, "nombre": "ALGORITMIA Y PROGRAMACIÓN", "creditos": 3},
    {"nivel": 3, "nombre": "FÍSICA MECÁNICA", "creditos": 3},
    {"nivel": 4, "nombre": "INGLÉS IV", "creditos": 1},
    {"nivel": 4, "nombre": "GESTIÓN DE MÉTODOS Y TIEMPOS", "creditos": 4},
    {"nivel": 4, "nombre": "INGENIERÍA ECONÓMICA", "creditos": 3},
    {"nivel": 4, "nombre": "DISEÑO DE EXPERIMENTOS Y ANÁLISIS DE REGRESIÓN", "creditos": 3},
    {"nivel": 4, "nombre": "OPTIMIZACIÓN", "creditos": 3},
    {"nivel": 4, "nombre": "TERMODINÁMICA", "creditos": 3},
    {"nivel": 5, "nombre": "INGLÉS V", "creditos": 1},
    {"nivel": 5, "nombre": "INVESTIGACIÓN OPERATIVA", "creditos": 3},
    {"nivel": 5, "nombre": "GESTIÓN FINANCIERA", "creditos": 3},
    {"nivel": 5, "nombre": "PLANEACIÓN Y CONTROL DE LA PRODUCCIÓN", "creditos": 3},
    {"nivel": 5, "nombre": "PROCESOS ESTOCÁSTICOS Y ANÁLISIS DE DECISIÓN", "creditos": 3},
    {"nivel": 6, "nombre": "INGLÉS VI", "creditos": 1},
    {"nivel": 6, "nombre": "GESTIÓN TECNOLÓGICA", "creditos": 3},
    {"nivel": 6, "nombre": "NORMALIZACIÓN Y CONTROL DE CALIDAD", "creditos": 3},
    {"nivel": 6, "nombre": "SIMULACIÓN", "creditos": 3},
    {"nivel": 6, "nombre": "SEGURIDAD Y SALUD EN EL TRABAJO", "creditos": 3},
    {"nivel": 7, "nombre": "GESTIÓN AMBIENTAL", "creditos": 3},
    {"nivel": 7, "nombre": "FORMULACIÓN Y EVALUACIÓN DE PROYECTOS", "creditos": 3},
    {"nivel": 7, "nombre": "GESTIÓN LOGÍSTICA Y DE LA CADENA DE SUMINISTRO", "creditos": 3},
    {"nivel": 7, "nombre": "MODELACIÓN DE SISTEMAS Y SIMULACIÓN DE PROCESOS", "creditos": 3},
    {"nivel": 8, "nombre": "GESTIÓN DEL TALENTO HUMANO", "creditos": 3},
    {"nivel": 8, "nombre": "GESTIÓN DE SERVICIOS", "creditos": 3},
    {"nivel": 8, "nombre": "PLANIFICACIÓN Y CONTROL DE LA PRODUCCIÓN", "creditos": 3},
    {"nivel": 8, "nombre": "PLANEACIÓN ESTRATÉGICA", "creditos": 3},
    {"nivel": 9, "nombre": "INVESTIGACIÓN DE MERCADOS Y ANÁLISIS DE LA COMPETENCIA", "creditos": 3},
    {"nivel": 9, "nombre": "PRÁCTICAS PROFESIONALES", "creditos": 3},
]

# Cursos y su configuración
courses = {}
consecutivo = 1
for materia in materias:
    codigo = generar_codigo(materia['nombre'], materia['nivel'], materia['creditos'], consecutivo)
    courses[codigo] = {
        'Semestres': [materia['nivel']],
        'Cupo': 30 if materia['nivel'] < 4 else 25 if materia['nivel'] < 7 else 20,
        'HTD': calcular_horas(materia['creditos'])[0],
        'HTI': calcular_horas(materia['creditos'])[1],
        'Nombre': materia['nombre']
    }
    consecutivo += 1

# Archivos de nombres y apellidos
first_names = read_names('https://raw.githubusercontent.com/YorladysArgumedo06/byte-forge-parte-2-/339cb25ae56f9824da41d226d86cbdb59a9abb5d/nombres.csv')
last_names = read_names('https://raw.githubusercontent.com/YorladysArgumedo06/byte-forge-parte-2-/339cb25ae56f9824da41d226d86cbdb59a9abb5d/apellidos.csv')

# Generar y distribuir estudiantes
students = generate_students(1000, first_names, last_names)
students = distribute_students(students)

# Crear archivos de cursos
create_course_files(students, courses, 'Ruta Trabajo Final')

# Finalizar el log de eventos con un resumen
total_files = sum([len(files) for r, d, files in os.walk('Ruta Trabajo Final')])
print(f"Total de archivos creados: {total_files}")
print(f"Total de acciones realizadas: {total_files * 2}")  # Cada archivo implica crear CSV y Excel, así que se multiplica por 2
# Out:
# Sistema: Linux
# Nodo: c930f233b8ec
# Release: 6.1.85+
# Versión: #1 SMP PREEMPT_DYNAMIC Sun Apr 28 14:29:16 UTC 2024
# Máquina: x86_64
# Procesador: x86_64
# _____________________________________________________________________________________
# Inicio de la creación de archivos de cursos
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-30-1.csv. Tiempo: 0:00:00.008218
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-30-1.xlsx. Tiempo: 0:00:00.602766
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-30-2.csv. Tiempo: 0:00:00.001418
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-30-2.xlsx. Tiempo: 0:00:00.019039
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-30-3.csv. Tiempo: 0:00:00.001677
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-30-3.xlsx. Tiempo: 0:00:00.021358
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-30-4.csv. Tiempo: 0:00:00.001447
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-30-4.xlsx. Tiempo: 0:00:00.017028
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-20-5.csv. Tiempo: 0:00:00.001434
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ING111/ING111-Inglési-20-5.xlsx. Tiempo: 0:00:00.019115
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-30-1.csv. Tiempo: 0:00:00.001711
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-30-1.xlsx. Tiempo: 0:00:00.021410
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-30-2.csv. Tiempo: 0:00:00.001423
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-30-2.xlsx. Tiempo: 0:00:00.016369
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-30-3.csv. Tiempo: 0:00:00.001374
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-30-3.xlsx. Tiempo: 0:00:00.021496
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-30-4.csv. Tiempo: 0:00:00.001463
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-30-4.xlsx. Tiempo: 0:00:00.023683
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-20-5.csv. Tiempo: 0:00:00.001319
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/INT112/INT112-Introducciónalaingenieríaindustrial-20-5.xlsx. Tiempo: 0:00:00.019089
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-30-1.csv. Tiempo: 0:00:00.001388
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-30-1.xlsx. Tiempo: 0:00:00.020504
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-30-2.csv. Tiempo: 0:00:00.001341
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-30-2.xlsx. Tiempo: 0:00:00.020657
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-30-3.csv. Tiempo: 0:00:00.001519
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-30-3.xlsx. Tiempo: 0:00:00.021807
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-30-4.csv. Tiempo: 0:00:00.001294
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-30-4.xlsx. Tiempo: 0:00:00.017519
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-20-5.csv. Tiempo: 0:00:00.001445
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/ÁLG133/ÁLG133-Álgebraytrigonometría-20-5.xlsx. Tiempo: 0:00:00.014492
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-30-1.csv. Tiempo: 0:00:00.001401
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-30-1.xlsx. Tiempo: 0:00:00.016995
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-30-2.csv. Tiempo: 0:00:00.001796
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-30-2.xlsx. Tiempo: 0:00:00.018237
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-30-3.csv. Tiempo: 0:00:00.001519
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-30-3.xlsx. Tiempo: 0:00:00.022491
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-30-4.csv. Tiempo: 0:00:00.001429
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-30-4.xlsx. Tiempo: 0:00:00.024437
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-20-5.csv. Tiempo: 0:00:00.001271
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/GEO134/GEO134-Geometríavectorialyanalítica-20-5.xlsx. Tiempo: 0:00:00.020080
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-30-1.csv. Tiempo: 0:00:00.001399
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-30-1.xlsx. Tiempo: 0:00:00.021084
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-30-2.csv. Tiempo: 0:00:00.002096
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-30-2.xlsx. Tiempo: 0:00:00.021069
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-30-3.csv. Tiempo: 0:00:00.001532
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-30-3.xlsx. Tiempo: 0:00:00.021377
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-30-4.csv. Tiempo: 0:00:00.001854
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-30-4.xlsx. Tiempo: 0:00:00.015420
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-20-5.csv. Tiempo: 0:00:00.002322
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/CÁL135/CÁL135-Cálculodiferencial-20-5.xlsx. Tiempo: 0:00:00.017390
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-30-1.csv. Tiempo: 0:00:00.002840
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-30-1.xlsx. Tiempo: 0:00:00.023589
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-30-2.csv. Tiempo: 0:00:00.001303
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-30-2.xlsx. Tiempo: 0:00:00.016686
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-30-3.csv. Tiempo: 0:00:00.001992
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-30-3.xlsx. Tiempo: 0:00:00.021347
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-30-4.csv. Tiempo: 0:00:00.001390
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-30-4.xlsx. Tiempo: 0:00:00.016668
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-20-5.csv. Tiempo: 0:00:00.001767
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/LEC136/LEC136-Lectoescritura-20-5.xlsx. Tiempo: 0:00:00.018194
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-30-1.csv. Tiempo: 0:00:00.001112
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-30-1.xlsx. Tiempo: 0:00:00.023395
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-30-2.csv. Tiempo: 0:00:00.001795
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-30-2.xlsx. Tiempo: 0:00:00.022141
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-30-3.csv. Tiempo: 0:00:00.001169
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-30-3.xlsx. Tiempo: 0:00:00.016874
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-30-4.csv. Tiempo: 0:00:00.003020
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-30-4.xlsx. Tiempo: 0:00:00.022076
# Creado archivo CSV: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-20-5.csv. Tiempo: 0:00:00.001683
# Creado archivo Excel: Ruta Trabajo Final/Semestre 1/VIV117/VIV117-Vivamoslauniversidad-20-5.xlsx. Tiempo: 0:00:00.016287
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-30-1.csv. Tiempo: 0:00:00.001099
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-30-1.xlsx. Tiempo: 0:00:00.019980
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-30-2.csv. Tiempo: 0:00:00.001181
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-30-2.xlsx. Tiempo: 0:00:00.016286
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-30-3.csv. Tiempo: 0:00:00.001458
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-30-3.xlsx. Tiempo: 0:00:00.018902
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-30-4.csv. Tiempo: 0:00:00.002071
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-30-4.xlsx. Tiempo: 0:00:00.020419
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-10-5.csv. Tiempo: 0:00:00.001899
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ING218/ING218-Inglésii-10-5.xlsx. Tiempo: 0:00:00.014661
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-30-1.csv. Tiempo: 0:00:00.001448
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-30-1.xlsx. Tiempo: 0:00:00.041506
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-30-2.csv. Tiempo: 0:00:00.001682
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-30-2.xlsx. Tiempo: 0:00:00.069901
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-30-3.csv. Tiempo: 0:00:00.006009
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-30-3.xlsx. Tiempo: 0:00:00.092613
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-30-4.csv. Tiempo: 0:00:00.012497
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-30-4.xlsx. Tiempo: 0:00:00.039049
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-10-5.csv. Tiempo: 0:00:00.003277
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/GES239/GES239-Gestióndelasorganizaciones-10-5.xlsx. Tiempo: 0:00:00.036798
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-30-1.csv. Tiempo: 0:00:00.002370
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-30-1.xlsx. Tiempo: 0:00:00.024198
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-30-2.csv. Tiempo: 0:00:00.001442
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-30-2.xlsx. Tiempo: 0:00:00.037722
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-30-3.csv. Tiempo: 0:00:00.001647
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-30-3.xlsx. Tiempo: 0:00:00.049149
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-30-4.csv. Tiempo: 0:00:00.001410
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-30-4.xlsx. Tiempo: 0:00:00.037267
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-10-5.csv. Tiempo: 0:00:00.002233
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/HAB2310/HAB2310-Habilidadesgerenciales-10-5.xlsx. Tiempo: 0:00:00.027709
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-30-1.csv. Tiempo: 0:00:00.001567
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-30-1.xlsx. Tiempo: 0:00:00.061894
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-30-2.csv. Tiempo: 0:00:00.001470
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-30-2.xlsx. Tiempo: 0:00:00.024841
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-30-3.csv. Tiempo: 0:00:00.020725
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-30-3.xlsx. Tiempo: 0:00:00.039663
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-30-4.csv. Tiempo: 0:00:00.003904
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-30-4.xlsx. Tiempo: 0:00:00.063687
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-10-5.csv. Tiempo: 0:00:00.005960
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/ÁLG2311/ÁLG2311-Álgebralineal-10-5.xlsx. Tiempo: 0:00:00.023886
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-30-1.csv. Tiempo: 0:00:00.001555
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-30-1.xlsx. Tiempo: 0:00:00.090946
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-30-2.csv. Tiempo: 0:00:00.003869
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-30-2.xlsx. Tiempo: 0:00:00.132649
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-30-3.csv. Tiempo: 0:00:00.016784
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-30-3.xlsx. Tiempo: 0:00:00.086919
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-30-4.csv. Tiempo: 0:00:00.005476
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-30-4.xlsx. Tiempo: 0:00:00.055954
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-10-5.csv. Tiempo: 0:00:00.006399
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/CÁL2312/CÁL2312-Cálculointegral-10-5.xlsx. Tiempo: 0:00:00.069105
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-30-1.csv. Tiempo: 0:00:00.001564
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-30-1.xlsx. Tiempo: 0:00:00.098991
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-30-2.csv. Tiempo: 0:00:00.011735
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-30-2.xlsx. Tiempo: 0:00:00.082645
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-30-3.csv. Tiempo: 0:00:00.002488
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-30-3.xlsx. Tiempo: 0:00:00.102016
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-30-4.csv. Tiempo: 0:00:00.003954
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-30-4.xlsx. Tiempo: 0:00:00.069752
# Creado archivo CSV: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-10-5.csv. Tiempo: 0:00:00.004458
# Creado archivo Excel: Ruta Trabajo Final/Semestre 2/DES2313/DES2313-Descubriendolafísica-10-5.xlsx. Tiempo: 0:00:00.068305
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/ING3114/ING3114-Inglésiii-30-1.csv. Tiempo: 0:00:00.015183
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/ING3114/ING3114-Inglésiii-30-1.xlsx. Tiempo: 0:00:00.083932
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/ING3114/ING3114-Inglésiii-30-2.csv. Tiempo: 0:00:00.001643
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/ING3114/ING3114-Inglésiii-30-2.xlsx. Tiempo: 0:00:00.076908
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/ING3114/ING3114-Inglésiii-30-3.csv. Tiempo: 0:00:00.001543
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/ING3114/ING3114-Inglésiii-30-3.xlsx. Tiempo: 0:00:00.098758
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/ING3114/ING3114-Inglésiii-30-4.csv. Tiempo: 0:00:00.001527
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/ING3114/ING3114-Inglésiii-30-4.xlsx. Tiempo: 0:00:00.092738
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/GES3315/GES3315-Gestióncontable-30-1.csv. Tiempo: 0:00:00.023842
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/GES3315/GES3315-Gestióncontable-30-1.xlsx. Tiempo: 0:00:00.122822
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/GES3315/GES3315-Gestióncontable-30-2.csv. Tiempo: 0:00:00.001522
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/GES3315/GES3315-Gestióncontable-30-2.xlsx. Tiempo: 0:00:00.059026
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/GES3315/GES3315-Gestióncontable-30-3.csv. Tiempo: 0:00:00.008016
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/GES3315/GES3315-Gestióncontable-30-3.xlsx. Tiempo: 0:00:00.147181
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/GES3315/GES3315-Gestióncontable-30-4.csv. Tiempo: 0:00:00.009359
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/GES3315/GES3315-Gestióncontable-30-4.xlsx. Tiempo: 0:00:00.108638
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/TEO3316/TEO3316-Teoríageneraldesistemas-30-1.csv. Tiempo: 0:00:00.010020
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/TEO3316/TEO3316-Teoríageneraldesistemas-30-1.xlsx. Tiempo: 0:00:00.100222
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/TEO3316/TEO3316-Teoríageneraldesistemas-30-2.csv. Tiempo: 0:00:00.005617
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/TEO3316/TEO3316-Teoríageneraldesistemas-30-2.xlsx. Tiempo: 0:00:00.083824
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/TEO3316/TEO3316-Teoríageneraldesistemas-30-3.csv. Tiempo: 0:00:00.003973
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/TEO3316/TEO3316-Teoríageneraldesistemas-30-3.xlsx. Tiempo: 0:00:00.079859
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/TEO3316/TEO3316-Teoríageneraldesistemas-30-4.csv. Tiempo: 0:00:00.009886
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/TEO3316/TEO3316-Teoríageneraldesistemas-30-4.xlsx. Tiempo: 0:00:00.092610
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/PRO3317/PRO3317-Probabilidadeinferenciaestadística-30-1.csv. Tiempo: 0:00:00.011547
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/PRO3317/PRO3317-Probabilidadeinferenciaestadística-30-1.xlsx. Tiempo: 0:00:00.132334
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/PRO3317/PRO3317-Probabilidadeinferenciaestadística-30-2.csv. Tiempo: 0:00:00.004158
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/PRO3317/PRO3317-Probabilidadeinferenciaestadística-30-2.xlsx. Tiempo: 0:00:00.107101
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/PRO3317/PRO3317-Probabilidadeinferenciaestadística-30-3.csv. Tiempo: 0:00:00.023166
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/PRO3317/PRO3317-Probabilidadeinferenciaestadística-30-3.xlsx. Tiempo: 0:00:00.132437
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/PRO3317/PRO3317-Probabilidadeinferenciaestadística-30-4.csv. Tiempo: 0:00:00.003626
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/PRO3317/PRO3317-Probabilidadeinferenciaestadística-30-4.xlsx. Tiempo: 0:00:00.130098
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/ALG3318/ALG3318-Algoritmiayprogramación-30-1.csv. Tiempo: 0:00:00.001686
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/ALG3318/ALG3318-Algoritmiayprogramación-30-1.xlsx. Tiempo: 0:00:00.101179
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/ALG3318/ALG3318-Algoritmiayprogramación-30-2.csv. Tiempo: 0:00:00.008887
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/ALG3318/ALG3318-Algoritmiayprogramación-30-2.xlsx. Tiempo: 0:00:00.097672
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/ALG3318/ALG3318-Algoritmiayprogramación-30-3.csv. Tiempo: 0:00:00.006118
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/ALG3318/ALG3318-Algoritmiayprogramación-30-3.xlsx. Tiempo: 0:00:00.123636
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/ALG3318/ALG3318-Algoritmiayprogramación-30-4.csv. Tiempo: 0:00:00.007810
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/ALG3318/ALG3318-Algoritmiayprogramación-30-4.xlsx. Tiempo: 0:00:00.073023
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/FÍS3319/FÍS3319-Físicamecánica-30-1.csv. Tiempo: 0:00:00.002405
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/FÍS3319/FÍS3319-Físicamecánica-30-1.xlsx. Tiempo: 0:00:00.160591
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/FÍS3319/FÍS3319-Físicamecánica-30-2.csv. Tiempo: 0:00:00.004845
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/FÍS3319/FÍS3319-Físicamecánica-30-2.xlsx. Tiempo: 0:00:00.093168
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/FÍS3319/FÍS3319-Físicamecánica-30-3.csv. Tiempo: 0:00:00.016635
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/FÍS3319/FÍS3319-Físicamecánica-30-3.xlsx. Tiempo: 0:00:00.084372
# Creado archivo CSV: Ruta Trabajo Final/Semestre 3/FÍS3319/FÍS3319-Físicamecánica-30-4.csv. Tiempo: 0:00:00.020021
# Creado archivo Excel: Ruta Trabajo Final/Semestre 3/FÍS3319/FÍS3319-Físicamecánica-30-4.xlsx. Tiempo: 0:00:00.061081
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-25-1.csv. Tiempo: 0:00:00.001899
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-25-1.xlsx. Tiempo: 0:00:00.070051
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-25-2.csv. Tiempo: 0:00:00.009415
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-25-2.xlsx. Tiempo: 0:00:00.043463
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-25-3.csv. Tiempo: 0:00:00.003489
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-25-3.xlsx. Tiempo: 0:00:00.042259
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-25-4.csv. Tiempo: 0:00:00.004631
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-25-4.xlsx. Tiempo: 0:00:00.053124
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-10-5.csv. Tiempo: 0:00:00.007108
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4120/ING4120-Inglésiv-10-5.xlsx. Tiempo: 0:00:00.033405
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-25-1.csv. Tiempo: 0:00:00.005775
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-25-1.xlsx. Tiempo: 0:00:00.037433
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-25-2.csv. Tiempo: 0:00:00.001454
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-25-2.xlsx. Tiempo: 0:00:00.028380
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-25-3.csv. Tiempo: 0:00:00.001414
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-25-3.xlsx. Tiempo: 0:00:00.032735
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-25-4.csv. Tiempo: 0:00:00.001351
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-25-4.xlsx. Tiempo: 0:00:00.023373
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-10-5.csv. Tiempo: 0:00:00.001320
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/GES4421/GES4421-Gestióndemétodosytiempos-10-5.xlsx. Tiempo: 0:00:00.039726
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-25-1.csv. Tiempo: 0:00:00.001489
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-25-1.xlsx. Tiempo: 0:00:00.039869
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-25-2.csv. Tiempo: 0:00:00.003735
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-25-2.xlsx. Tiempo: 0:00:00.033849
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-25-3.csv. Tiempo: 0:00:00.008647
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-25-3.xlsx. Tiempo: 0:00:00.058323
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-25-4.csv. Tiempo: 0:00:00.003501
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-25-4.xlsx. Tiempo: 0:00:00.045989
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-10-5.csv. Tiempo: 0:00:00.001431
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/ING4322/ING4322-Ingenieríaeconómica-10-5.xlsx. Tiempo: 0:00:00.041599
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-25-1.csv. Tiempo: 0:00:00.007124
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-25-1.xlsx. Tiempo: 0:00:00.038938
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-25-2.csv. Tiempo: 0:00:00.003641
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-25-2.xlsx. Tiempo: 0:00:00.039522
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-25-3.csv. Tiempo: 0:00:00.001452
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-25-3.xlsx. Tiempo: 0:00:00.069361
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-25-4.csv. Tiempo: 0:00:00.007929
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-25-4.xlsx. Tiempo: 0:00:00.078110
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-10-5.csv. Tiempo: 0:00:00.007693
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/DIS4323/DIS4323-Diseñodeexperimentosyanálisisderegresión-10-5.xlsx. Tiempo: 0:00:00.036388
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-25-1.csv. Tiempo: 0:00:00.001417
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-25-1.xlsx. Tiempo: 0:00:00.024927
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-25-2.csv. Tiempo: 0:00:00.001500
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-25-2.xlsx. Tiempo: 0:00:00.049713
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-25-3.csv. Tiempo: 0:00:00.001437
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-25-3.xlsx. Tiempo: 0:00:00.039297
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-25-4.csv. Tiempo: 0:00:00.001432
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-25-4.xlsx. Tiempo: 0:00:00.059145
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-10-5.csv. Tiempo: 0:00:00.001345
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/OPT4324/OPT4324-Optimización-10-5.xlsx. Tiempo: 0:00:00.034848
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/TER4325/TER4325-Termodinámica-25-1.csv. Tiempo: 0:00:00.001579
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/TER4325/TER4325-Termodinámica-25-1.xlsx. Tiempo: 0:00:00.047249
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/TER4325/TER4325-Termodinámica-25-2.csv. Tiempo: 0:00:00.003570
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/TER4325/TER4325-Termodinámica-25-2.xlsx. Tiempo: 0:00:00.023982
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/TER4325/TER4325-Termodinámica-25-3.csv. Tiempo: 0:00:00.001441
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/TER4325/TER4325-Termodinámica-25-3.xlsx. Tiempo: 0:00:00.054389
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/TER4325/TER4325-Termodinámica-25-4.csv. Tiempo: 0:00:00.005029
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/TER4325/TER4325-Termodinámica-25-4.xlsx. Tiempo: 0:00:00.022580
# Creado archivo CSV: Ruta Trabajo Final/Semestre 4/TER4325/TER4325-Termodinámica-10-5.csv. Tiempo: 0:00:00.001532
# Creado archivo Excel: Ruta Trabajo Final/Semestre 4/TER4325/TER4325-Termodinámica-10-5.xlsx. Tiempo: 0:00:00.027336
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/ING5126/ING5126-Inglésv-25-1.csv. Tiempo: 0:00:00.001565
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/ING5126/ING5126-Inglésv-25-1.xlsx. Tiempo: 0:00:00.023957
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/ING5126/ING5126-Inglésv-25-2.csv. Tiempo: 0:00:00.001501
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/ING5126/ING5126-Inglésv-25-2.xlsx. Tiempo: 0:00:00.063376
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/ING5126/ING5126-Inglésv-25-3.csv. Tiempo: 0:00:00.001739
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/ING5126/ING5126-Inglésv-25-3.xlsx. Tiempo: 0:00:00.055474
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/ING5126/ING5126-Inglésv-25-4.csv. Tiempo: 0:00:00.001741
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/ING5126/ING5126-Inglésv-25-4.xlsx. Tiempo: 0:00:00.032464
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/INV5327/INV5327-Investigaciónoperativa-25-1.csv. Tiempo: 0:00:00.001600
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/INV5327/INV5327-Investigaciónoperativa-25-1.xlsx. Tiempo: 0:00:00.024262
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/INV5327/INV5327-Investigaciónoperativa-25-2.csv. Tiempo: 0:00:00.001507
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/INV5327/INV5327-Investigaciónoperativa-25-2.xlsx. Tiempo: 0:00:00.025926
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/INV5327/INV5327-Investigaciónoperativa-25-3.csv. Tiempo: 0:00:00.001505
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/INV5327/INV5327-Investigaciónoperativa-25-3.xlsx. Tiempo: 0:00:00.029507
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/INV5327/INV5327-Investigaciónoperativa-25-4.csv. Tiempo: 0:00:00.002123
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/INV5327/INV5327-Investigaciónoperativa-25-4.xlsx. Tiempo: 0:00:00.030191
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/GES5328/GES5328-Gestiónfinanciera-25-1.csv. Tiempo: 0:00:00.007969
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/GES5328/GES5328-Gestiónfinanciera-25-1.xlsx. Tiempo: 0:00:00.063843
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/GES5328/GES5328-Gestiónfinanciera-25-2.csv. Tiempo: 0:00:00.001474
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/GES5328/GES5328-Gestiónfinanciera-25-2.xlsx. Tiempo: 0:00:00.052831
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/GES5328/GES5328-Gestiónfinanciera-25-3.csv. Tiempo: 0:00:00.015037
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/GES5328/GES5328-Gestiónfinanciera-25-3.xlsx. Tiempo: 0:00:00.044125
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/GES5328/GES5328-Gestiónfinanciera-25-4.csv. Tiempo: 0:00:00.001481
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/GES5328/GES5328-Gestiónfinanciera-25-4.xlsx. Tiempo: 0:00:00.089573
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/PLA5329/PLA5329-Planeaciónycontroldelaproducción-25-1.csv. Tiempo: 0:00:00.003463
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/PLA5329/PLA5329-Planeaciónycontroldelaproducción-25-1.xlsx. Tiempo: 0:00:00.021659
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/PLA5329/PLA5329-Planeaciónycontroldelaproducción-25-2.csv. Tiempo: 0:00:00.001408
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/PLA5329/PLA5329-Planeaciónycontroldelaproducción-25-2.xlsx. Tiempo: 0:00:00.045940
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/PLA5329/PLA5329-Planeaciónycontroldelaproducción-25-3.csv. Tiempo: 0:00:00.002758
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/PLA5329/PLA5329-Planeaciónycontroldelaproducción-25-3.xlsx. Tiempo: 0:00:00.038001
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/PLA5329/PLA5329-Planeaciónycontroldelaproducción-25-4.csv. Tiempo: 0:00:00.001550
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/PLA5329/PLA5329-Planeaciónycontroldelaproducción-25-4.xlsx. Tiempo: 0:00:00.045630
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/PRO5330/PRO5330-Procesosestocásticosyanálisisdedecisión-25-1.csv. Tiempo: 0:00:00.001680
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/PRO5330/PRO5330-Procesosestocásticosyanálisisdedecisión-25-1.xlsx. Tiempo: 0:00:00.060013
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/PRO5330/PRO5330-Procesosestocásticosyanálisisdedecisión-25-2.csv. Tiempo: 0:00:00.007783
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/PRO5330/PRO5330-Procesosestocásticosyanálisisdedecisión-25-2.xlsx. Tiempo: 0:00:00.060310
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/PRO5330/PRO5330-Procesosestocásticosyanálisisdedecisión-25-3.csv. Tiempo: 0:00:00.001463
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/PRO5330/PRO5330-Procesosestocásticosyanálisisdedecisión-25-3.xlsx. Tiempo: 0:00:00.041117
# Creado archivo CSV: Ruta Trabajo Final/Semestre 5/PRO5330/PRO5330-Procesosestocásticosyanálisisdedecisión-25-4.csv. Tiempo: 0:00:00.004855
# Creado archivo Excel: Ruta Trabajo Final/Semestre 5/PRO5330/PRO5330-Procesosestocásticosyanálisisdedecisión-25-4.xlsx. Tiempo: 0:00:00.026457
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/ING6131/ING6131-Inglésvi-25-1.csv. Tiempo: 0:00:00.002967
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/ING6131/ING6131-Inglésvi-25-1.xlsx. Tiempo: 0:00:00.092467
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/ING6131/ING6131-Inglésvi-25-2.csv. Tiempo: 0:00:00.001621
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/ING6131/ING6131-Inglésvi-25-2.xlsx. Tiempo: 0:00:00.061465
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/ING6131/ING6131-Inglésvi-25-3.csv. Tiempo: 0:00:00.002241
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/ING6131/ING6131-Inglésvi-25-3.xlsx. Tiempo: 0:00:00.031566
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/ING6131/ING6131-Inglésvi-25-4.csv. Tiempo: 0:00:00.001373
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/ING6131/ING6131-Inglésvi-25-4.xlsx. Tiempo: 0:00:00.025314
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/GES6332/GES6332-Gestióntecnológica-25-1.csv. Tiempo: 0:00:00.001341
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/GES6332/GES6332-Gestióntecnológica-25-1.xlsx. Tiempo: 0:00:00.022296
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/GES6332/GES6332-Gestióntecnológica-25-2.csv. Tiempo: 0:00:00.001455
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/GES6332/GES6332-Gestióntecnológica-25-2.xlsx. Tiempo: 0:00:00.035683
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/GES6332/GES6332-Gestióntecnológica-25-3.csv. Tiempo: 0:00:00.005077
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/GES6332/GES6332-Gestióntecnológica-25-3.xlsx. Tiempo: 0:00:00.047652
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/GES6332/GES6332-Gestióntecnológica-25-4.csv. Tiempo: 0:00:00.003320
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/GES6332/GES6332-Gestióntecnológica-25-4.xlsx. Tiempo: 0:00:00.102711
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/NOR6333/NOR6333-Normalizaciónycontroldecalidad-25-1.csv. Tiempo: 0:00:00.005877
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/NOR6333/NOR6333-Normalizaciónycontroldecalidad-25-1.xlsx. Tiempo: 0:00:00.080966
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/NOR6333/NOR6333-Normalizaciónycontroldecalidad-25-2.csv. Tiempo: 0:00:00.001886
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/NOR6333/NOR6333-Normalizaciónycontroldecalidad-25-2.xlsx. Tiempo: 0:00:00.030833
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/NOR6333/NOR6333-Normalizaciónycontroldecalidad-25-3.csv. Tiempo: 0:00:00.002087
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/NOR6333/NOR6333-Normalizaciónycontroldecalidad-25-3.xlsx. Tiempo: 0:00:00.041921
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/NOR6333/NOR6333-Normalizaciónycontroldecalidad-25-4.csv. Tiempo: 0:00:00.001862
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/NOR6333/NOR6333-Normalizaciónycontroldecalidad-25-4.xlsx. Tiempo: 0:00:00.059518
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/SIM6334/SIM6334-Simulación-25-1.csv. Tiempo: 0:00:00.002145
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/SIM6334/SIM6334-Simulación-25-1.xlsx. Tiempo: 0:00:00.071315
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/SIM6334/SIM6334-Simulación-25-2.csv. Tiempo: 0:00:00.001667
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/SIM6334/SIM6334-Simulación-25-2.xlsx. Tiempo: 0:00:00.053105
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/SIM6334/SIM6334-Simulación-25-3.csv. Tiempo: 0:00:00.002262
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/SIM6334/SIM6334-Simulación-25-3.xlsx. Tiempo: 0:00:00.023758
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/SIM6334/SIM6334-Simulación-25-4.csv. Tiempo: 0:00:00.014849
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/SIM6334/SIM6334-Simulación-25-4.xlsx. Tiempo: 0:00:00.058416
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/SEG6335/SEG6335-Seguridadysaludeneltrabajo-25-1.csv. Tiempo: 0:00:00.002909
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/SEG6335/SEG6335-Seguridadysaludeneltrabajo-25-1.xlsx. Tiempo: 0:00:00.025548
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/SEG6335/SEG6335-Seguridadysaludeneltrabajo-25-2.csv. Tiempo: 0:00:00.001505
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/SEG6335/SEG6335-Seguridadysaludeneltrabajo-25-2.xlsx. Tiempo: 0:00:00.052477
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/SEG6335/SEG6335-Seguridadysaludeneltrabajo-25-3.csv. Tiempo: 0:00:00.004653
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/SEG6335/SEG6335-Seguridadysaludeneltrabajo-25-3.xlsx. Tiempo: 0:00:00.045311
# Creado archivo CSV: Ruta Trabajo Final/Semestre 6/SEG6335/SEG6335-Seguridadysaludeneltrabajo-25-4.csv. Tiempo: 0:00:00.003673
# Creado archivo Excel: Ruta Trabajo Final/Semestre 6/SEG6335/SEG6335-Seguridadysaludeneltrabajo-25-4.xlsx. Tiempo: 0:00:00.040576
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-20-1.csv. Tiempo: 0:00:00.001550
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-20-1.xlsx. Tiempo: 0:00:00.039228
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-20-2.csv. Tiempo: 0:00:00.001641
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-20-2.xlsx. Tiempo: 0:00:00.018883
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-20-3.csv. Tiempo: 0:00:00.001431
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-20-3.xlsx. Tiempo: 0:00:00.048823
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-20-4.csv. Tiempo: 0:00:00.002112
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-20-4.xlsx. Tiempo: 0:00:00.024973
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-10-5.csv. Tiempo: 0:00:00.001401
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7336/GES7336-Gestiónambiental-10-5.xlsx. Tiempo: 0:00:00.016600
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-20-1.csv. Tiempo: 0:00:00.001470
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-20-1.xlsx. Tiempo: 0:00:00.019815
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-20-2.csv. Tiempo: 0:00:00.002304
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-20-2.xlsx. Tiempo: 0:00:00.029977
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-20-3.csv. Tiempo: 0:00:00.001283
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-20-3.xlsx. Tiempo: 0:00:00.018457
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-20-4.csv. Tiempo: 0:00:00.001517
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-20-4.xlsx. Tiempo: 0:00:00.018801
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-10-5.csv. Tiempo: 0:00:00.001432
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/FOR7337/FOR7337-Formulaciónyevaluacióndeproyectos-10-5.xlsx. Tiempo: 0:00:00.026985
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-20-1.csv. Tiempo: 0:00:00.001466
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-20-1.xlsx. Tiempo: 0:00:00.028042
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-20-2.csv. Tiempo: 0:00:00.001406
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-20-2.xlsx. Tiempo: 0:00:00.021780
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-20-3.csv. Tiempo: 0:00:00.001372
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-20-3.xlsx. Tiempo: 0:00:00.032501
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-20-4.csv. Tiempo: 0:00:00.001483
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-20-4.xlsx. Tiempo: 0:00:00.034309
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-10-5.csv. Tiempo: 0:00:00.001437
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/GES7338/GES7338-Gestiónlogísticaydelacadenadesuministro-10-5.xlsx. Tiempo: 0:00:00.027247
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-20-1.csv. Tiempo: 0:00:00.001482
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-20-1.xlsx. Tiempo: 0:00:00.020529
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-20-2.csv. Tiempo: 0:00:00.001362
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-20-2.xlsx. Tiempo: 0:00:00.030958
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-20-3.csv. Tiempo: 0:00:00.001372
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-20-3.xlsx. Tiempo: 0:00:00.050830
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-20-4.csv. Tiempo: 0:00:00.004305
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-20-4.xlsx. Tiempo: 0:00:00.042474
# Creado archivo CSV: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-10-5.csv. Tiempo: 0:00:00.003666
# Creado archivo Excel: Ruta Trabajo Final/Semestre 7/MOD7339/MOD7339-Modelacióndesistemasysimulacióndeprocesos-10-5.xlsx. Tiempo: 0:00:00.034418
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/GES8340/GES8340-Gestióndeltalentohumano-20-1.csv. Tiempo: 0:00:00.001737
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/GES8340/GES8340-Gestióndeltalentohumano-20-1.xlsx. Tiempo: 0:00:00.034150
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/GES8340/GES8340-Gestióndeltalentohumano-20-2.csv. Tiempo: 0:00:00.002458
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/GES8340/GES8340-Gestióndeltalentohumano-20-2.xlsx. Tiempo: 0:00:00.049682
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/GES8340/GES8340-Gestióndeltalentohumano-20-3.csv. Tiempo: 0:00:00.003571
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/GES8340/GES8340-Gestióndeltalentohumano-20-3.xlsx. Tiempo: 0:00:00.087820
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/GES8340/GES8340-Gestióndeltalentohumano-20-4.csv. Tiempo: 0:00:00.004649
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/GES8340/GES8340-Gestióndeltalentohumano-20-4.xlsx. Tiempo: 0:00:00.067196
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/GES8341/GES8341-Gestióndeservicios-20-1.csv. Tiempo: 0:00:00.005094
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/GES8341/GES8341-Gestióndeservicios-20-1.xlsx. Tiempo: 0:00:00.022583
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/GES8341/GES8341-Gestióndeservicios-20-2.csv. Tiempo: 0:00:00.001408
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/GES8341/GES8341-Gestióndeservicios-20-2.xlsx. Tiempo: 0:00:00.026396
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/GES8341/GES8341-Gestióndeservicios-20-3.csv. Tiempo: 0:00:00.001471
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/GES8341/GES8341-Gestióndeservicios-20-3.xlsx. Tiempo: 0:00:00.023258
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/GES8341/GES8341-Gestióndeservicios-20-4.csv. Tiempo: 0:00:00.001470
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/GES8341/GES8341-Gestióndeservicios-20-4.xlsx. Tiempo: 0:00:00.024596
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/PLA8342/PLA8342-Planificaciónycontroldelaproducción-20-1.csv. Tiempo: 0:00:00.001439
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/PLA8342/PLA8342-Planificaciónycontroldelaproducción-20-1.xlsx. Tiempo: 0:00:00.019233
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/PLA8342/PLA8342-Planificaciónycontroldelaproducción-20-2.csv. Tiempo: 0:00:00.003051
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/PLA8342/PLA8342-Planificaciónycontroldelaproducción-20-2.xlsx. Tiempo: 0:00:00.023514
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/PLA8342/PLA8342-Planificaciónycontroldelaproducción-20-3.csv. Tiempo: 0:00:00.001490
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/PLA8342/PLA8342-Planificaciónycontroldelaproducción-20-3.xlsx. Tiempo: 0:00:00.019087
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/PLA8342/PLA8342-Planificaciónycontroldelaproducción-20-4.csv. Tiempo: 0:00:00.001430
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/PLA8342/PLA8342-Planificaciónycontroldelaproducción-20-4.xlsx. Tiempo: 0:00:00.018568
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/PLA8343/PLA8343-Planeaciónestratégica-20-1.csv. Tiempo: 0:00:00.001527
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/PLA8343/PLA8343-Planeaciónestratégica-20-1.xlsx. Tiempo: 0:00:00.059929
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/PLA8343/PLA8343-Planeaciónestratégica-20-2.csv. Tiempo: 0:00:00.001836
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/PLA8343/PLA8343-Planeaciónestratégica-20-2.xlsx. Tiempo: 0:00:00.035401
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/PLA8343/PLA8343-Planeaciónestratégica-20-3.csv. Tiempo: 0:00:00.001530
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/PLA8343/PLA8343-Planeaciónestratégica-20-3.xlsx. Tiempo: 0:00:00.127138
# Creado archivo CSV: Ruta Trabajo Final/Semestre 8/PLA8343/PLA8343-Planeaciónestratégica-20-4.csv. Tiempo: 0:00:00.001568
# Creado archivo Excel: Ruta Trabajo Final/Semestre 8/PLA8343/PLA8343-Planeaciónestratégica-20-4.xlsx. Tiempo: 0:00:00.023527
# Creado archivo CSV: Ruta Trabajo Final/Semestre 9/INV9344/INV9344-Investigacióndemercadosyanálisisdelacompetencia-20-1.csv. Tiempo: 0:00:00.001145
# Creado archivo Excel: Ruta Trabajo Final/Semestre 9/INV9344/INV9344-Investigacióndemercadosyanálisisdelacompetencia-20-1.xlsx. Tiempo: 0:00:00.017782
# Creado archivo CSV: Ruta Trabajo Final/Semestre 9/INV9344/INV9344-Investigacióndemercadosyanálisisdelacompetencia-20-2.csv. Tiempo: 0:00:00.001783
# Creado archivo Excel: Ruta Trabajo Final/Semestre 9/INV9344/INV9344-Investigacióndemercadosyanálisisdelacompetencia-20-2.xlsx. Tiempo: 0:00:00.015261
# Creado archivo CSV: Ruta Trabajo Final/Semestre 9/INV9344/INV9344-Investigacióndemercadosyanálisisdelacompetencia-20-3.csv. Tiempo: 0:00:00.002102
# Creado archivo Excel: Ruta Trabajo Final/Semestre 9/INV9344/INV9344-Investigacióndemercadosyanálisisdelacompetencia-20-3.xlsx. Tiempo: 0:00:00.017318
# Creado archivo CSV: Ruta Trabajo Final/Semestre 9/INV9344/INV9344-Investigacióndemercadosyanálisisdelacompetencia-10-4.csv. Tiempo: 0:00:00.001730
# Creado archivo Excel: Ruta Trabajo Final/Semestre 9/INV9344/INV9344-Investigacióndemercadosyanálisisdelacompetencia-10-4.xlsx. Tiempo: 0:00:00.014587
# Creado archivo CSV: Ruta Trabajo Final/Semestre 9/PRÁ9345/PRÁ9345-Prácticasprofesionales-20-1.csv. Tiempo: 0:00:00.001211
# Creado archivo Excel: Ruta Trabajo Final/Semestre 9/PRÁ9345/PRÁ9345-Prácticasprofesionales-20-1.xlsx. Tiempo: 0:00:00.019246
# Creado archivo CSV: Ruta Trabajo Final/Semestre 9/PRÁ9345/PRÁ9345-Prácticasprofesionales-20-2.csv. Tiempo: 0:00:00.001901
# Creado archivo Excel: Ruta Trabajo Final/Semestre 9/PRÁ9345/PRÁ9345-Prácticasprofesionales-20-2.xlsx. Tiempo: 0:00:00.022789
# Creado archivo CSV: Ruta Trabajo Final/Semestre 9/PRÁ9345/PRÁ9345-Prácticasprofesionales-20-3.csv. Tiempo: 0:00:00.008330
# Creado archivo Excel: Ruta Trabajo Final/Semestre 9/PRÁ9345/PRÁ9345-Prácticasprofesionales-20-3.xlsx. Tiempo: 0:00:00.019071
# Creado archivo CSV: Ruta Trabajo Final/Semestre 9/PRÁ9345/PRÁ9345-Prácticasprofesionales-10-4.csv. Tiempo: 0:00:00.001631
# Creado archivo Excel: Ruta Trabajo Final/Semestre 9/PRÁ9345/PRÁ9345-Prácticasprofesionales-10-4.xlsx. Tiempo: 0:00:00.015855
# Fin de la creación de archivos de cursos. Tiempo total: 0:00:12.938639
# Total de archivos creados: 406
# Total de acciones realizadas: 812

# %%
# Función para buscar un estudiante y sus cursos
def buscar_estudiante(nombre_completo, students, courses):
    estudiante = next((est for est in students if est['Nombre Completo'] == nombre_completo), None)
    if estudiante is None:
        return f"Error: El estudiante {nombre_completo} no existe."

    semestre = estudiante['Semestre']
    cursos_matriculados = [info['Nombre'] for code, info in courses.items() if semestre in info['Semestres']]
    cursos_str = "\n".join(cursos_matriculados)
    return f"Estudiante: {nombre_completo}\nSemestre: {semestre}\nCursos matriculados:\n{cursos_str}"

# Pedir al usuario el nombre del estudiante
nombre_estudiante = input("Ingrese el nombre completo del estudiante: ")
resultado = buscar_estudiante(nombre_estudiante, students, courses)
print(resultado)
